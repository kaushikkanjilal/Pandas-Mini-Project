# %%
import pandas as pd

# %%
df = pd.read_excel(r"E:\Panda\Excel_ sheet_for _working\super-store-sales-dataset-main\super-store-sales-dataset-main\Orders.xlsx")

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0       7981  CA-2014-103800 2014-01-03 2014-01-07  Standard Class
# 1        740  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 2        741  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 3        742  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 4       1760  CA-2014-141817 2014-01-05 2014-01-12  Standard Class
# ...      ...             ...        ...        ...             ...
# 1988    7681  CA-2014-133592 2014-12-31 2015-01-07  Standard Class
# 1989    7682  CA-2014-133592 2014-12-31 2015-01-07  Standard Class
# 1990    8603  US-2014-133949 2014-12-31 2014-12-31        Same Day
# 1991    8804  CA-2014-157644 2014-12-31 2015-01-01     First Class
# 1992    8805  CA-2014-157644 2014-12-31 2015-01-01     First Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 0       DP-13000     Darren Powers     Consumer  United States        Houston
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1993 entries, 0 to 1992
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         1993 non-null   int64
#  1   Order ID       1993 non-null   object
#  2   Order Date     1993 non-null   datetime64[ns]
#  3   Ship Date      1993 non-null   datetime64[ns]
#  4   Ship Mode      1993 non-null   object
#  5   Customer ID    1993 non-null   object
#  6   Customer Name  1993 non-null   object
#  7   Segment        1993 non-null   object
#  8   Country        1993 non-null   object
#  9   City           1993 non-null   object
#  10  State          1993 non-null   object
#  11  Postal Code    1993 non-null   int64
#  12  Region         1993 non-null   object
#  13  Product ID     1993 non-null   object
#  14  Category       1993 non-null   object
#  15  Sub-Category   1993 non-null   object
#  16  Product Name   1993 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  1993.000000                           1993
# mean   4969.400401  2014-08-11 11:47:21.344706560
# min       6.000000            2014-01-03 00:00:00
# 25%    2613.000000            2014-05-21 00:00:00
# 50%    4899.000000            2014-09-07 00:00:00
# 75%    7508.000000            2014-11-10 00:00:00
# max    9990.000000            2014-12-31 00:00:00
# std    2895.777922                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           1993   1993.000000   1993.000000  1993.000000
# mean   2014-08-15 11:43:01.234320128  56834.544405    242.974159     3.803813
# min              2014-01-07 00:00:00   1841.000000      0.852000     1.000000
# 25%              2014-05-26 00:00:00  27511.000000     16.224000     2.000000
# 50%              2014-09-11 00:00:00  60623.000000     51.968000     3.000000
# ...

# %%
df.groupby("Category")[["Sales","Profit"]].sum().sort_values(by="Sales",ascending=False)
# Out:
#                        Sales      Profit
# Category
# Technology       175278.2330  21492.8325
# Furniture        157192.8531   5457.7255
# Office Supplies  151776.4120  22593.4161

# %%
Sub_Category= df.groupby("Sub-Category")["Profit"].sum().sort_values(ascending=False)

# %%
Sub_Category
# Out:
# Sub-Category
# Phones         11808.0053
# Chairs          6955.0470
# Accessories     6402.7150
# Paper           6371.0214
# Binders         4739.7160
# Storage         4166.2788
# Copiers         2912.9433
# Appliances      2459.4999
# Furnishings     1972.8919
# Envelopes       1495.4788
# Art             1406.8031
# Labels          1286.0042
# Supplies         490.0556
# Machines         369.1689
# Fasteners        178.5583
# Bookcases       -346.1707
# Tables         -3124.0427
# Name: Profit, dtype: float64

# %%
Loss_Making_Sub_Category = Sub_Category[Sub_Category<0]

# %%
Loss_Making_Sub_Category.sort_values(ascending=True)
# Out:
# Sub-Category
# Tables      -3124.0427
# Bookcases    -346.1707
# Name: Profit, dtype: float64

# %%
Sales= df.groupby("Sub-Category")["Sales"].sum()

# %%
Sales
# Out:
# Sub-Category
# Accessories    25014.2720
# Appliances     15313.6250
# Art             6057.9820
# Binders        43488.2650
# Bookcases      20036.6776
# Chairs         77241.5760
# Copiers        10849.7820
# Envelopes       3855.7500
# Fasteners        661.3280
# Furnishings    13826.2340
# Labels          2841.3940
# Machines       62023.3730
# Paper          14834.9560
# Phones         77390.8060
# Storage        50329.0420
# Supplies       14394.0700
# Tables         46088.3655
# Name: Sales, dtype: float64

# %%
Average_Sales = Sales.mean()

# %%
Average_Sales
# Out:
# 28485.146947058824

# %%
Sales_Greater_Average_Sales=Sales[Sales>Average_Sales]

# %%
Sales_Greater_Average_Sales.sort_values(ascending=False)
# Out:
# Sub-Category
# Phones      77390.8060
# Chairs      77241.5760
# Machines    62023.3730
# Storage     50329.0420
# Tables      46088.3655
# Binders     43488.2650
# Name: Sales, dtype: float64

# %%
Total_profit =df["Profit"].sum()

# %%
Total_profit
# Out:
# 49543.974099999985

# %%
Category = df.groupby("Category")["Profit"].sum()

# %%
Total_Profit_Average=Category.mean()

# %%
Total_Profit_Average=Category.mean()

# %%
Total_Profit_Average
# Out:
# 16514.65803333333

# %%
Category_Profit_greater_Total_Profit_Average=Category[Category>Total_Profit_Average]

# %%
Category_Profit_greater_Total_Profit_Average
# Out:
# Category
# Office Supplies    22593.4161
# Technology         21492.8325
# Name: Profit, dtype: float64

# %%
Top_3_Customers=df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(3)

# %%
Top_3_Customers
# Out:
# Customer Name
# Sean Miller     23661.228
# Sanjit Chand    12876.480
# Becky Martin    10539.896
# Name: Sales, dtype: float64

# %%
Region_Max_Total_Profit=df.groupby("Region")["Profit"].sum().sort_values(ascending=False).head(1)

# %%
Region_Max_Total_Profit
# Out:
# Region
# West    20065.6912
# Name: Profit, dtype: float64

# %%
Five_Products_Total_Quantity = df.groupby("Product Name")["Quantity"].sum().sort_values(ascending=False).head()

# %%
Five_Products_Total_Quantity
# Out:
# Product Name
# Staple envelope                           54
# Staples                                   52
# KI Adjustable-Height Table                29
# Southworth 100% Résumé Paper, 24lb.       28
# Maxell 74 Minute CD-R Spindle, 50/Pack    24
# Name: Quantity, dtype: int64

# %%
Total_Sales=df.groupby("Category")["Sales"].sum()

# %%
Total_Sales
# Out:
# Category
# Furniture          157192.8531
# Office Supplies    151776.4120
# Technology         175278.2330
# Name: Sales, dtype: float64

# %%
Average_Category_Sales=Total_Sales.mean()

# %%
Average_Category_Sales
# Out:
# 161415.8327

# %%
Total_Sales_greater_Average_Category_Sales= Total_Sales[Total_Sales>Average_Category_Sales]

# %%
Total_Sales_greater_Average_Category_Sales
# Out:
# Category
# Technology    175278.233
# Name: Sales, dtype: float64
